# %%
import base64

with open("/Users/pedromaia/Desktop/Projects/Socket/pdfteste.pdf", "rb") as pdf_file:
    encoded_string = base64.b64encode(pdf_file.read())

# %%
file = open('new.pdf', 'wb')
file.write(base64.b64decode(encoded_string))
file.close()

# %%
import sys

sys.getsizeof(encoded_string)
# Out:
# 165525

# %%
print(2+2)
# Out:
# 4

# %%
base64.b64encode(bytes("E980E67BC2F06641F23E62A14329C883C6E31203DF3CF26A4C364DF2E5D9D081", encoding="UTF-8"))
import math

# %%
math.floor(len(encoded_string)/10000)
# Out:
# 16

# %%
len(encoded_string)%10000


INTERVAL = 10000
# Out:
# 5492

# %%
for i in range(math.floor(len(encoded_string)/INTERVAL)):
    print(i*INTERVAL, (i+1) * INTERVAL -1)
    if i == math.floor(len(encoded_string)/INTERVAL)-1:
        print((i+1)*INTERVAL, len(encoded_string)%INTERVAL + (i+1)*INTERVAL)
# Out:
# 0 9999
# 10000 19999
# 20000 29999
# 30000 39999
# 40000 49999
# 50000 59999
# 60000 69999
# 70000 79999
# 80000 89999
# 90000 99999
# 100000 109999
# 110000 119999
# 120000 129999
# 130000 139999
# 140000 149999
# 150000 159999
# 160000 165492

# %%
INTERVAL = 10000
string = b""
for i in range(math.floor(len(encoded_string)/INTERVAL)):
            print(i*INTERVAL, (i+1) * INTERVAL)
            
            string += encoded_string[i*INTERVAL:(i+1) * INTERVAL -1]

            if i == math.floor(len(encoded_string)/INTERVAL)-1:
                print((i+1)*INTERVAL, len(encoded_string)%INTERVAL + (i+1)*INTERVAL)
                string += encoded_string[(i+1)*INTERVAL:len(encoded_string)%INTERVAL + (i+1)*INTERVAL]

string
# Out:
# 0 10000
# 10000 20000
# 20000 30000
# 30000 40000
# 40000 50000
# 50000 60000
# 60000 70000
# 70000 80000
# 80000 90000
# 90000 100000
# 100000 110000
# 110000 120000
# 120000 130000
# 130000 140000
# 140000 150000
# 150000 160000
# 160000 165492
# b'...'
